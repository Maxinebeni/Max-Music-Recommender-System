# %%
import pandas as pd

# %%
df= pd.read_csv("/content/drive/MyDrive/content/spotify_millsongdata.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(5)
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df =df.sample(5000).drop('link', axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#            artist                  song  \
# 0    Cyndi Lauper        Midnight Radio
# 1    Eric Clapton   If I Needed Someone
# 2  Rolling Stones            Good Times
# 3  Gloria Estefan        Keep On Trying
# 4     Bing Crosby         Isle Of Capri
# 5         Misfits  Fiend Without A Face
# 6  Tragically Hip          Trickle Down
# 7        Zucchero           Lost Scents
# 8  Rolling Stones   Blinded By Rainbows
# 9          O.A.R.         Over And Over
#
#                                                 text
# 0  Rain falls hard  \r\nBurns dry  \r\nA dream  \...
# 1  If I needed someone to love  \r\nYou're the on...
# 2  Whoa la la ta ta  \r\nWhoa la la ta ta  \r\nLa...
# 3  Everybody is lazy  \r\nNobody wants to do anyt...
# 4  't Was on the Isle of Capri that I found her  ...
# 5  See the features of my rage  \r\nBegin to shoo...
# 6  Old lion's dying, got left behind  \r\nCut you...
# 7  Heading homeward, home I cannot find, oh love ...
# 8  Did you ever feel the pain  \r\nThat he felt u...
# 9  Sitting here waiting on a new situation  \r\nO...

# %%
df['text'][0]
# Out:
# "Rain falls hard  \r\nBurns dry  \r\nA dream  \r\nOr a song  \r\nThat hits you so hard  \r\nFilling you up  \r\nAnd suddenly gone  \r\n  \r\nBreath Feel Love  \r\nGive Free  \r\nKnow in you soul  \r\nLike your blood knows the way  \r\nFrom you heart to your brain  \r\nKnow that you're whole  \r\n  \r\nAnd you're shining  \r\nLike the brightest star  \r\nA transmission  \r\nOn the midnight radio  \r\nAnd you're spinning  \r\nLike a 45  \r\nBallerina  \r\nDancing to your rock and roll  \r\n  \r\nHere's to Patti  \r\nAnd Tina  \r\nAnd Yoko  \r\nAretha  \r\nAnd Nona  \r\nAnd Nico  \r\nAnd me  \r\n  \r\nAnd all the strange rock and rollers  \r\nYou know you're doing all right  \r\nSo hold on to each other  \r\nYou gotta hold on tonight  \r\n  \r\nAnd you're shining  \r\nLike the brightest stars  \r\nA transmission  \r\nOn the midnight radio  \r\n  \r\nAnd you're spinning  \r\nYour new 45's  \r\nAll the misfits and the losers  \r\nYeah, you know you're rock and rollers  \r\nSpinning to your rock and roll\r\n\r\n"

# %%
df.shape
# Out:
# (5000, 3)

# %% [markdown]
# Text Cleaning/ Text Preprocessing

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex = True)
print(df['text'])
# Out:
# 0       rain falls hard  \r burns dry  \r a dream  \r ...
# 1       if i needed someone to love  \r you're the one...
# 2       whoa la la ta ta  \r whoa la la ta ta  \r la l...
# 3       everybody is lazy  \r nobody wants to do anyth...
# 4       't was on the isle of capri that i found her  ...
#                               ...
# 4995    je t'aime te amo  \r ya tyibya i yublu  \r ani...
# 4996    lovely, you're always lovely  \r a vision, you...
# 4997    altamont, now, won't be the same  \r when we s...
# 4998    written by karla bonoff  \r (c) 1975 seagrape ...
# 4999    do you enjoy your sight inside?  \r   \r disco...
# Name: text, Length: 5000, dtype: object

# %%
# This line tokenizes the input text txt into a list of words using NLTK's word_tokenize function.
# It breaks the text into individual words.
import nltk
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

nltk.download('punkt')


def tokenization(txt):
    tokens = nltk.word_tokenize(txt)
    stemming = [stemmer.stem(w) for w in tokens]
    return " ".join(stemming)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df['text'] = df['text'].apply(lambda x: tokenization(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidvector = TfidfVectorizer(analyzer='word',stop_words='english')
matrix = tfidvector.fit_transform(df['text'])
similarity = cosine_similarity(matrix)

# %%
similarity[0]
# Out:
# array([1.        , 0.01567676, 0.05453448, ..., 0.03719069, 0.04331477,
#        0.00774865])

# %%
df[df['song'] == 'Midnight Radio']
# Out:
#          artist            song  \
# 0  Cyndi Lauper  Midnight Radio
#
#                                                 text
# 0  rain fall hard burn dri a dream or a song that...

# %%
def recommendation(song_df):
    idx = df[df['song'] == song_df].index[0]
    distances = sorted(list(enumerate(similarity[idx])),reverse=True,key=lambda x:x[1])

    songs = []
    for m_id in distances[1:6]:
        songs.append(df.iloc[m_id[0]].song)

    return songs

# %%
recommendation('Midnight Radio')
# Out:
# ['Spin, Spin, Spin',
#  'Rock Bottom',
#  "Rock 'n' Roll Is Dead",
#  'Still Love Rock N Roll',
#  "Long Live Rock 'n' Roll"]

# %%
import pickle
pickle.dump(similarity,open('similarity.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))

# %%
import os

# Get the current working directory in Colab
cwd = '/content'
file_list = os.listdir(cwd)

# List the files in the current directory
print("Files in the current directory:")
for file in file_list:
    print(file)
# Out:
# Files in the current directory:
# .config
# df.pkl
# similarity.pkl
# drive
# .ipynb_checkpoints
# sample_data

# %%
import shutil
import os

# List of files to include in the archive
files_to_include = ['df.pkl', 'similarity.pkl']

# Create a temporary directory
temp_dir = '/content/temp_archive'
os.makedirs(temp_dir, exist_ok=True)

# Copy the selected files to the temporary directory
for file in files_to_include:
    shutil.copy(os.path.join('/content', file), os.path.join(temp_dir, file))

# Archive the files in the temporary directory
shutil.make_archive("/content/selected_files", 'zip', temp_dir)

# Remove the temporary directory and its contents
shutil.rmtree(temp_dir)
